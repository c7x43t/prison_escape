# %% [markdown]
# # Prisoner's Dilemma - Overview and Comparison of Classic and Machine Learning Strategies
#
# 	                               Prisoner A
# 	                         --------------------
# 	                         |Cooperate| Defect |
# 	               |---------|---------|--------|
# 	               |Cooperate| (1, 1)  | (0, 3) |
# 	    Prisoner B |---------|---------|--------|
# 	               | Defect  | (3, 0)  | (2, 2) |
# 	               ------------------------------

# %%
import axelrod as axl
# axl.seed(4)

OUTPUT_DIR = "./output/"
TOURNAMENT_RESULTS_FILE = "tournament_results.png"
TOURNAMENT_PAYOFFS_FILE = "tournament_payoffs.png"

players = []

# %% [markdown]
# # Strategies

# %% [markdown]
# ### Classic

# %%
classic = [
  axl.Cooperator(), # Always cooperates
           axl.Defector(), # Always defects
           axl.Random(), # Random actions
           axl.TitForTat(), # Initially cooperates, then mimimcs opponent's moves
           axl.Grumpy(), # Defects after a certain level of grumpiness which increases when the opponent defects and decreases when the opponent co-operates
           axl.Alternator(),# Alternates between cooperating and defecting
           ] 
classic = [
  axl.ALLCorALLD(),
axl.AON2(),
axl.APavlov2006(),
axl.APavlov2011(),
axl.Adaptive(),
axl.AdaptiveTitForTat(),
axl.AdaptorBrief(),
axl.AdaptorLong(),
axl.Aggravater(),
axl.Alexei(),
axl.Alternator(),
axl.AlternatorHunter(),
axl.AntiCycler(),
axl.AntiTitForTat(),
axl.Appeaser(),
axl.ArrogantQLearner(),
axl.AverageCopier(),
axl.BackStabber(),
axl.BetterAndBetter(),
axl.Bully(),
axl.BurnBothEnds(),
axl.BushMosteller(),
axl.Calculator(),
axl.Capri(),
axl.CautiousQLearner(),
axl.CollectiveStrategy(),
axl.ContriteTitForTat(),
axl.Cooperator(),
axl.CooperatorHunter(),
axl.CycleHunter(),
axl.CyclerCCCCCD(),
axl.CyclerCCCD(),
axl.CyclerCCCDCD(),
axl.CyclerCCD(),
axl.CyclerDC(),
axl.CyclerDDC(),
axl.DBS(),
axl.Darwin(),
axl.Defector(),
axl.DefectorHunter(),
axl.DelayedAON1(),
axl.Desperate(),
axl.Detective(),
axl.DoubleCrosser(),
axl.DoubleResurrection(),
axl.Doubler(),
axl.DynamicTwoTitsForTat(),
axl.EasyGo(),
axl.EugineNier(),
axl.EventualCycleHunter(),

axl.FirmButFair(),
axl.FirstByAnonymous(),
axl.FirstByDavis(),
axl.FirstByDowning(),
axl.FirstByFeld(),
axl.FirstByGraaskamp(),
axl.FirstByGrofman(),
axl.FirstByJoss(),
axl.FirstByNydegger(),
axl.FirstByShubik(),
axl.FirstBySteinAndRapoport(),
axl.FirstByTidemanAndChieruzzi(),
axl.FirstByTullock(),
axl.FoolMeOnce(),
axl.ForgetfulFoolMeOnce(),
axl.ForgetfulGrudger(),
axl.Forgiver(),
axl.ForgivingTitForTat(),
axl.Fortress3(),
axl.Fortress4(),
axl.GTFT(),
axl.GeneralSoftGrudger(),
axl.GoByMajority(),
axl.GoByMajority10(),
axl.GoByMajority20(),
axl.GoByMajority40(),
axl.GoByMajority5(),
axl.Golden(),
axl.Gradual(),
axl.GradualKiller(),
axl.Grudger(),
axl.GrudgerAlternator(),
axl.Grumpy(),
axl.Handshake(),
axl.HardGoByMajority(),
axl.HardGoByMajority10(),
axl.HardGoByMajority20(),
axl.HardGoByMajority40(),
axl.HardGoByMajority5(),
axl.HardProber(),
axl.HardTitFor2Tats(),
axl.HardTitForTat(),
axl.HesitantQLearner(),
axl.Hopeless(),
axl.Inverse(),
axl.InversePunisher(),
axl.KnowledgeableWorseAndWorse(),
axl.LevelPunisher(),
axl.LimitedRetaliate(),
axl.LimitedRetaliate2(),
axl.LimitedRetaliate3(),
axl.MEM2(),
axl.MathConstantHunter(),
axl.Michaelos(),
axl.NTitsForMTats(),
axl.NaiveProber(),
axl.Negation(),
axl.NiceAverageCopier(),
axl.OmegaTFT(),
axl.OnceBitten(),
axl.OppositeGrudger(),
axl.OriginalGradual(),
axl.PSOGambler1_1_1(),
axl.PSOGambler2_2_2(),
axl.PSOGambler2_2_2_Noise05(),
axl.PSOGamblerMem1(),
axl.Pi(),
axl.Predator(),
axl.Prober(),
axl.Prober2(),
axl.Prober3(),
axl.Prober4(),
axl.Pun1(),
axl.Punisher(),
axl.Raider(),
axl.Random(),
axl.RandomHunter(),
axl.RandomTitForTat(),
axl.RemorsefulProber(),
axl.Resurrection(),
axl.Retaliate(),
axl.Retaliate2(),
axl.Retaliate3(),
axl.RevisedDowning(),
axl.Ripoff(),
axl.RiskyQLearner(),
axl.SecondByAppold(),
axl.SecondByBlack(),
axl.SecondByBorufsen(),
axl.SecondByCave(),
axl.SecondByChampion(),
axl.SecondByColbert(),
axl.SecondByEatherley(),
axl.SecondByGetzler(),
axl.SecondByGladstein(),
axl.SecondByGraaskampKatzen(),
axl.SecondByGrofman(),
axl.SecondByHarrington(),
axl.SecondByKluepfel(),
axl.SecondByLeyvraz(),
axl.SecondByMikkelson(),
axl.SecondByRichardHufford(),
axl.SecondByRowsam(),
axl.SecondByTester(),
axl.SecondByTidemanAndChieruzzi(),
axl.SecondByTranquilizer(),
axl.SecondByWeiner(),
axl.SecondByWhite(),
axl.SecondByWmAdams(),
axl.SecondByYamachi(),
axl.SelfSteem(),
axl.ShortMem(),
axl.SlowTitForTwoTats2(),
axl.SneakyTitForTat(),
axl.SoftGrudger(),
axl.SoftJoss(),
axl.SolutionB1(),
axl.SolutionB5(),
axl.SpitefulTitForTat(),
axl.SpitefulCC(),
axl.Stalker(),
axl.StochasticCooperator(),
axl.StochasticWSLS(),
axl.SuspiciousTitForTat(),
axl.TF1(),
axl.TF2(),
axl.TF3(),
axl.ThueMorse(),
axl.ThueMorseInverse(),
axl.Thumper(),
axl.TitFor2Tats(),
axl.TitForTat(),
axl.TrickyCooperator(),
axl.TrickyDefector(),
axl.TrickyLevelPunisher(),
axl.TwoTitsForTat(),
axl.UsuallyCooperates(),
axl.UsuallyDefects(),
axl.VeryBad(),
axl.Willing(),
axl.WinShiftLoseStay(),
axl.WinStayLoseShift(),
axl.Winner12(),
axl.Winner21(),
axl.WorseAndWorse(),
axl.WorseAndWorse2(),
axl.WorseAndWorse3(),
axl.ZDExtort2(),
axl.ZDExtort2v2(),
axl.ZDExtort3(),
axl.ZDExtort4(),
axl.ZDExtortion(),
axl.ZDGTFT2(),
axl.ZDGen2(),
axl.ZDMem2(),
axl.ZDMischief(),
axl.ZDSet2(),
axl.e(),
]
players += classic

# %% [markdown]
# ### Neural Networks
#
# All Neural Network based strategies have the following features:
# * Opponent’s first move is C
# * Opponent’s first move is D
# * Opponent’s second move is C
# * Opponent’s second move is D
# * Player’s previous move is C
# * Player’s previous move is D
# * Player’s second previous move is C
# * Player’s second previous move is D
# * Opponent’s previous move is C
# * Opponent’s previous move is D
# * Opponent’s second previous move is C
# * Opponent’s second previous move is D
# * Total opponent cooperations
# * Total opponent defections
# * Total player cooperations
# * Total player defections
# * Round number

# %%
neural_networks = [
axl.EvolvedANN(),
axl.EvolvedANN5(),
axl.EvolvedANNNoise05(),
axl.EvolvedFSM16(),
axl.EvolvedFSM16Noise05(),
axl.EvolvedFSM4(),
axl.EvolvedFSM6(),
axl.EvolvedHMM5(),
axl.EvolvedLookerUp1_1_1(),
axl.EvolvedLookerUp2_2_2(),
                  
                  ] # ANN with a hidden layer of size 5, trained with noise=0.05
players += neural_networks

# %% [markdown]
# # Tournament

# %%
tournament = axl.Tournament(players=players)
results = tournament.play(processes=6,progress_bar=True,build_results=True)
winners = results.ranked_names
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:14<00:00,  1.78it/s]

# %% [markdown]
# # Results

# %%
results_plot = axl.Plot(results)
plot = results_plot.boxplot()
plot.show()
plot.savefig(OUTPUT_DIR+TOURNAMENT_RESULTS_FILE)
# Out:
# C:\Users\c7x43t_user\AppData\Local\Temp\ipykernel_153032\3606276523.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %%
plot = results_plot.payoff()
plot.show()
plot.savefig(OUTPUT_DIR+TOURNAMENT_PAYOFFS_FILE)
# Out:
# C:\Users\c7x43t_user\AppData\Local\Temp\ipykernel_153032\1929057580.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot.show()

# %%
import numpy as np
from rich import print as rprint

DOCS_DIR = "./docs/"

# Assuming 'results' is your tournament results object
# cooperating_rating = results.cooperating_rating
# good_partner_rating = results.good_partner_rating
# eigenmoses_rating = results.eigenmoses_rating
# eigenjesus_rating = results.eigenjesus_rating
# wins = np.sum(results.wins, axis=1)
# avg_scores = np.mean(results.scores, axis=1)
# avg_normalised_scores = np.mean(results.normalised_scores, axis=1)
# rankings = np.array(results.ranking) + 1  # Adjusting for 0-based index
# avg_payoffs = [np.mean(payoff) for payoff in results.payoffs]
# payoff_stddevs = np.mean(results.payoff_stddevs, axis=1)
# avg_payoff_diffs = np.mean(results.payoff_diffs_means, axis=1)
# total_cooperation = np.sum(results.cooperation, axis=1)
# normalised_cooperation = np.mean(results.normalised_cooperation, axis=1)
# initial_cooperation_count = results.initial_cooperation_count
# initial_cooperation_rate = results.initial_cooperation_rate
# ranked_names = results.ranked_names


sorted_indices = np.argsort(results.ranking)

# Use these indices to sort all metrics and the names
ranked_names = np.array(results.ranked_names)[sorted_indices]
rankings = np.flip(np.array(results.ranking)[sorted_indices] + 1)  # Adjusting for 0-based index
cooperating_rating = results.cooperating_rating # np.array(results.cooperating_rating)[sorted_indices]
good_partner_rating = results.good_partner_rating # np.array(results.good_partner_rating)[sorted_indices]
eigenmoses_rating = results.eigenmoses_rating #np.array(results.eigenmoses_rating)[sorted_indices]
eigenjesus_rating =results.eigenjesus_rating # np.array(results.eigenjesus_rating)[sorted_indices]
wins = [np.sum(payoff) for payoff in results.wins]# np.sum(results.wins, axis=1)[sorted_indices]
wins = wins / np.array(wins).max()
avg_scores = [np.mean(score) for score in results.scores] #np.mean(results.scores, axis=1)[sorted_indices]
avg_normalised_scores = [np.mean(score) for score in results.normalised_scores]  #np.mean(results.normalised_scores, axis=1)[sorted_indices]
avg_payoffs = np.array([np.mean(payoff) for payoff in results.payoffs])[sorted_indices]
# avg_payoffs = np.mean(results.payoffs, axis=1)[sorted_indices]
# print(type(results.payoffs))
avg_payoffs = [np.mean(payoff) for payoff in results.payoffs]
payoff_stddevs = [np.mean(payoff) for payoff in results.payoff_stddevs]# np.mean(results.payoff_stddevs, axis=1)[sorted_indices]
avg_payoff_diffs =[np.mean(payoff) for payoff in results.payoff_diffs_means]# np.mean(results.payoff_diffs_means, axis=1)[sorted_indices]
total_cooperation = [np.sum(payoff) for payoff in results.cooperation]#np.sum(results.cooperation, axis=1)[sorted_indices]
normalised_cooperation = [np.mean(payoff) for payoff in results.normalised_cooperation] #np.mean(results.normalised_cooperation, axis=1)[sorted_indices]
initial_cooperation_count = results.initial_cooperation_count#np.array(results.initial_cooperation_count)[sorted_indices]
initial_cooperation_rate = results.initial_cooperation_rate#np.array(results.initial_cooperation_rate)[sorted_indices]
player_names = [player.name for player in players]

# Compile metrics into a single array
metrics_array = np.vstack([
    ranked_names,
    rankings,
    cooperating_rating,
    good_partner_rating,
    eigenmoses_rating,
    eigenjesus_rating,
    wins,
    #avg_scores,
    avg_normalised_scores,
    #avg_payoffs,
    payoff_stddevs,
    #avg_payoff_diffs,
    #total_cooperation,
    #normalised_cooperation,
    #initial_cooperation_count,
    initial_cooperation_rate
]).T

titles = np.vstack([
    "Strategy",
    "Ranking",
    "Cooperating Rating",
    "Good Partner Rating",
    "Eigenmoses",
    "Eigenjesus",
    "Winrate",
    #"Avg. Score",
    "Avg. Norm. Score",
    #"Avg. Payoff",
    "Score SD",
    #"Avg. Payoff Diff.",
    #"Total Cooperation",
    #"Norm. Cooperation",
    #"Init. Cooperation Count",
    "Init. Cooperation Rate"
]).T

import codecs, json




# Function to determine if a string represents a float
def is_float(element):
    try:
        float(element)
        return True
    except ValueError:
        return False

# Function to round floats in the array, including those represented as strings
def round_floats(arr, precision=3):
    def round_element(e):
        if isinstance(e, float):
            return round(e, precision)
        elif isinstance(e, str) and is_float(e):
            return round(float(e), precision)
        elif isinstance(e, list):
            return [round_element(x) for x in e]
        else:
            return e
    return [round_element(row) for row in arr]


# Convert NumPy arrays to lists for JSON serialization
titles_list = titles.tolist()[0]  # Convert titles to a list and get the first element since it's transposed

# Skip the first element (which is assumed to be titles in your setup), round floats in the rest
metrics_list = round_floats(metrics_array.tolist(), 3)

# Prepend titles to the metrics list
modified_array = [titles_list] + metrics_list

# Define the file paths
json_file_path = 'results.json'
js_file_path = 'results.js'

# Assuming OUTPUT_DIR is defined
# For example: OUTPUT_DIR = "/path/to/output/"

print(results)

# Write the modified array to a JSON file
with codecs.open(OUTPUT_DIR + json_file_path, 'w', encoding='utf-8') as file:
    json.dump(modified_array, file, separators=(',', ':'), sort_keys=True, indent=4)

# Convert the modified array to a JSON string for embedding in JavaScript
json_string = json.dumps(modified_array, separators=(',', ':'), sort_keys=True, indent=4)

# Strings to prepend and append to the JS content
prepend_str = "const results = "
append_str = ";\nwindow.results = results;"

# Write the JSON string to a JavaScript file with prepend and append strings
with codecs.open(DOCS_DIR + js_file_path, 'w', encoding='utf-8') as file:
    file.write(prepend_str + json_string + append_str)
